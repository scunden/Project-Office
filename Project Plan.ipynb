# %% [markdown]
# ## Project Plan and Steps
# <br>
#
# **Main Goal**: Anlaysis of air time per character in the show the office, in order to determine who is statistically more important/funniest to the show
#
# 1. **Data Exploration and Cleaning** - Extracting our data and ensuring that there are no major discrepancies that lie within. This step and the next are typically the most time consuming steps in any project
# <br>
#
# 2. **Data Wrangling** - This step will consist of restructuring and re formatting our data in a way that will allow for our analyses.
# <br>
#
# 3. **Analysis** - We will run a multiple regression from start to finish, going through all th statistical assumptions to the coefficient interpretation
# <br>
#
# 4. **Visualizations** - We will use Tableau to visualize some of the results of our analysis, as well as any interesting pattern we observed in our data. The goal here will be to create a visual story of our process
# <br>
#
# 5. **Reporting** - We will eventually document our results into a blog format, and submit it to a datascience blog, in the hope of being published!

# %% [markdown]
# ## Getting Familiar with Jupyter, and Pandas

# %% [markdown]
# what is pandas, dataframes, series
# basic manipulation - index, slicing, filtering, loc and iloc
#
# Uploading Data
# excel, csv
#
# Data Exploration
# head, unique, value_counts, normalize
#
# Aggregating data
#
# gihub basics

# %% [markdown]
# ### 1. Pandas, DataFrames and Series

# %% [markdown]
# Library that allows you to manipulate data
#
# uploaded data -> data frame

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('farmers_markets_from_usda.csv')

# %%
df2 = df.set_index('FMID')

# %%
df2.columns
# Out:
# Index(['MarketName', 'Website', 'Facebook', 'Twitter', 'Youtube', 'OtherMedia',
#        'street', 'city', 'County', 'State', 'zip', 'Season1Date',
#        'Season1Time', 'Season2Date', 'Season2Time', 'Season3Date',
#        'Season3Time', 'Season4Date', 'Season4Time', 'x', 'y', 'Location',
#        'Credit', 'WIC', 'WICcash', 'SFMNP', 'SNAP', 'Organic', 'Bakedgoods',
#        'Cheese', 'Crafts', 'Flowers', 'Eggs', 'Seafood', 'Herbs', 'Vegetables',
#        'Honey', 'Jams', 'Maple', 'Meat', 'Nursery', 'Nuts', 'Plants',
#        'Poultry', 'Prepared', 'Soap', 'Trees', 'Wine', 'Coffee', 'Beans',
#        'Fruits', 'Grains', 'Juices', 'Mushrooms', 'PetFood', 'Tofu',
#        'WildHarvested', 'updateTime'],
#       dtype='object')

# %%
# selecting columns - pass a list of columns, into the df[]
df[['FMID','Facebook','State']]

# Get all the columns
df.columns

# Get index
df.index

# Get shape of df
df.shape

# inplace parameter determines whether method is applied to the dataframe in memory
df.sort_values(['FMID'], inplace=True) # Change the df in memory
df.sort_values(['FMID'], inplace=False) # Print out the result of the method but wont affect df in memory
# Out:
#          FMID                                           Facebook  \
# 8765  2000036  https://www.facebook.com/pages/YMCA-Farmers-Ma...
# 8512  2000035  https://www.facebook.com/pages/Westside-Tailga...
# 8013  2000034                                                NaN
# 7858  2000033   https://www.facebook.com/groups/419868484808209/
# 7800  2000032         https://www.facebook.com/HHEDCMobileMarket
# ...       ...                                                ...
# 5926  1000010                                                NaN
# 7121  1000009  https://www.facebook.com/pages/South-Shore-Far...
# 6767  1000007                                                NaN
# 2278  1000003       https://www.facebook.com/EdmoreFarmersMarket
# 6938  1000001                                                NaN
#
#                State
# 8765        Michigan
# 8512         Alabama
# 8013         Florida
# 7858      New Mexico
# 7800        Missouri
# ...              ...
# 5926  South Carolina
# ...

# %%
df.shape
# Out:
# (8804, 60)

# %%
# Series is a one column data frame
# df['State']
# df.State 

# Create a new column
df['Name'] = 1

# %%
df.head()
# Out:
#          FMID                                   MarketName  \
# 1898  1019334                       Derwood Farmers Market
# 1312  1004972  Christian "Shan" Hendricks Vegetable Market
# 4178  1004880                      La Reine Farmers Market
# 216   1004881               Anne Heyliger Vegetable Market
# 6594  1004967          Rothschild Francis Vegetable Market
#
#                        Website  \
# 1898  http://DerwoodMarket.org
# 1312                       NaN
# 4178                       NaN
# 216                        NaN
# 6594                       NaN
#
#                                              Facebook  \
# 1898  https://www.facebook.com/MilkladyFarmersMarkets
# 1312                                              NaN
# 4178                                              NaN
# 216                                               NaN
# 6594                                              NaN
#
#                                   Twitter  \
# ...

# %%
df_ca = df[df['State']=='California']

# %%
df_ca.head()
# Out:
#          FMID                                   MarketName  \
# 6711  1007252          San Clemente Village Farmers Market
# 958   1010783                      Calexico Farmers Market
# 5327  1008453            Neighborhood House Farmers Market
# 2397  1007856                             Empire Polo Club
# 5697  1012591  Old Town La Quinta Certified Farmers Market
#
#                                                 Website  \
# 6711                                                NaN
# 958   http://calexicorecreation.org/events/calexico-...
# 5327                              http://www.nhclx.org
# 2397                                                NaN
# 5697             http://www.certifiedfarmersmarkets.org
#
#                                               Facebook           Twitter  \
# 6711                                               NaN               NaN
# 958          https://www.facebook.com/clxfarmersmarket               NaN
# ...

# %%
# Filtering using conditions
df[(df['State']=='California')&(df['Cheese']=='Y')].head()
# Out:
#          FMID                                   MarketName  \
# 5697  1012591  Old Town La Quinta Certified Farmers Market
# 3962  1002907         Joshua Tree Certified Farmers Market
# 5864  1012587        Palm Desert Certified Farmers Market
# 5865  1012558       Palm Springs Certified Farmers' Market
# 594   1005949                      Big Bear Farmers Market
#
#                                      Website  \
# 5697  http://www.certifiedfarmersmarkets.org
# 3962  http://www.joshuatreefarmersmarket.com
# 5864  http://www.certifiedfarmersmarkets.org
# 5865  http://www.certifiedfarmersmarkets.org
# 594   http://www.highdesertfarmersmarket.com
#
#                                                Facebook           Twitter  \
# 5697   https://www.facebook.com/CertifiedFarmersMarket/  @PSFARMERSMARKET
# 3962  https://www.facebook.com/pages/Joshua-Tree-Far...               NaN
# 5864   https://www.facebook.com/CertifiedFarmersMarket/  @PSFARMERSMARKET
# ...

# %%
state_list = ['California', 'New York']
df[df['State'].isin(state_list)].head()

# Same statement, different syntax

df[(df['State']=='California')|(df['State']=='New York'))].head()
# Out:
#          FMID                        MarketName  \
# 2191  1012383   East Hampton Farmers Market LLC
# 6656  1002412         Sag Harbor Farmers Market
# 3486  1005993  Hayground School Farmers' Market
# 3252  1005163         Greenport Farmers' Market
# 3357  1012165       Hampton Bays Farmers Market
#
#                                     Website  \
# 2191                                    NaN
# 6656  http://www.sagharborfarmersmarket.org
# 3486                                    NaN
# 3252  http://www.GreenportFarmersMarket.com
# 3357               http://www.stmaryshb.org
#
#                                                Facebook  \
# 2191                    East Hampton Farmers Market LLC
# 6656                                                NaN
# 3486                                                NaN
# 3252    https://www.facebook.com/GreenportFarmersMarket
# 3357  https://www.facebook.com/hamptonbaysfarmersmarket
#
#                                  Twitter Youtube  \
# ...

# %%
df['State'].unique()
# Out:
# array(['Maryland', 'Virgin Islands', 'Puerto Rico', 'Maine',
#        'Massachusetts', 'New Hampshire', 'Rhode Island', 'Connecticut',
#        'Vermont', 'New York', 'California', 'New Jersey', 'Pennsylvania',
#        'Delaware', 'Virginia', 'North Carolina', 'District of Columbia',
#        'West Virginia', 'South Carolina', 'Iowa', 'Florida', 'Ohio',
#        'Georgia', 'Tennessee', 'Michigan', 'Kentucky', 'Indiana',
#        'Alabama', 'Wisconsin', 'Illinois', 'Mississippi', 'Missouri',
#        'Louisiana', 'Arkansas', 'Minnesota', 'Oklahoma', 'Texas',
#        'Kansas', 'Nebraska', 'South Dakota', 'North Dakota', 'New Mexico',
#        'Colorado', 'Wyoming', 'Montana', 'Arizona', 'Utah', 'Idaho',
#        'Nevada', 'Oregon', 'Washington', 'Alaska', 'Hawaii'], dtype=object)

# %%
df['State'].value_counts().reset_index()
# Out:
#                    index  State
# 0             California    760
# 1               New York    673
# 2               Michigan    343
# 3               Illinois    338
# 4                   Ohio    336
# 5          Massachusetts    326
# 6           Pennsylvania    312
# 7              Wisconsin    311
# 8                Florida    264
# 9               Virginia    263
# 10              Missouri    256
# 11        North Carolina    255
# 12                 Texas    236
# 13                  Iowa    227
# 14             Minnesota    203
# 15               Indiana    201
# 16            Washington    176
# 17               Georgia    169
# 18              Maryland    165
# 19              Colorado    161
# 20                Oregon    160
# 21           Connecticut    158
# 22            New Jersey    156
# 23               Alabama    140
# 24              Kentucky    140
# 25        South Carolina    133
# 26             Tennessee    133
# 27                Kansas    120
# ...
